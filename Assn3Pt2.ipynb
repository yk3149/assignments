# %%
# PART 2: POOCH

# %%
import sys
# !{sys.executable} -m pip install pooch

import pooch
import os

# Set up Pooch to download a file
# This example downloads a small air quality dataset
file_path = pooch.retrieve(
    url="https://github.com/pandas-dev/pandas/raw/main/doc/data/air_quality_no2.csv",
    known_hash=None
)

print("File downloaded to:", file_path)
print("File exists:", os.path.exists(file_path))
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pooch in /home/yk3149/.local/lib/python3.11/site-packages (1.9.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pooch) (4.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pooch) (25.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from pooch) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/sw/anaconda3/2023.09/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2026.1.4)
# File downloaded to: /home/yk3149/.cache/pooch/458dad453f6a48e510cd544bef1854e3-air_quality_no2.csv
# File exists: True

# %%
import os
import pooch

# 1. Verify the file was downloaded (5 points)
# Check the file size
file_size = os.path.getsize(file_path)
print(f"File size: {file_size} bytes")

# Count how many lines the file has
line_count = 0
with open(file_path, "r") as f:
    for line in f:
        line_count += 1

print(f"Number of lines: {line_count}")


# 2. Download another file (10 points)
# Example: NASA global temperature dataset (simple CSV version)

my_url = "https://raw.githubusercontent.com/datasets/global-temp/master/data/monthly.csv"

my_file = pooch.retrieve(
    url=my_url,
    known_hash=None
)

print("\nNew file downloaded to:", my_file)
print("New file size:", os.path.getsize(my_file), "bytes")


# 3. Create a data inventory (5 points)
print("\nData Inventory:")
print("1. meteorites.csv - NASA meteorite landings")
print("2. air_quality_no2.csv - Air quality NO2 measurements")
print("3. monthly.csv - Global temperature anomalies dataset")
# Out:
# Downloading data from 'https://raw.githubusercontent.com/datasets/global-temp/master/data/monthly.csv' to file '/home/yk3149/.cache/pooch/5a3e1acd6b381aee143d16b9a8cd3e5e-monthly.csv'.
# SHA256 hash of downloaded file: b21c8bfd6a775b04f1c42cc70c91e95246b06570391a8f5dec0b9f31888658f1
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# File size: 31984 bytes
# Number of lines: 1036
#
# New file downloaded to: /home/yk3149/.cache/pooch/5a3e1acd6b381aee143d16b9a8cd3e5e-monthly.csv
# New file size: 83924 bytes
#
# Data Inventory:
# 1. meteorites.csv - NASA meteorite landings
# 2. air_quality_no2.csv - Air quality NO2 measurements
# 3. monthly.csv - Global temperature anomalies dataset
